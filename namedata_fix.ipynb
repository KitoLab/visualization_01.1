# %%
import pandas as pd
import re

# %%
#読み込むデータ設定
data_path = 'members1.csv'

#出力ファイル
output_csv = 'members_fix.csv'

# %%
#membersの読み込み
members = pd.read_csv(data_path, encoding = 'ANSI')

# %%
#member = pd.DataFrame(members[['name','id'].unique(), columns = ['name'])
#bef_id = pd.DataFrame(members['id'] , columns = ['bef_id'])
members_list_1 = members[['name', 'id']].fillna("a")
print(members_list_1)
# Out:
#              name                                id
# 0      ﾌｸｼﾏ ｾｲﾀﾛｳ  25b8db9251d0c85065e7f4db9e493b72
# 1       ﾔﾅｷﾞｵｶ ｴﾐ  b127f88c4f12f2ebee7d50020cebc7dc
# 2      ﾂｶｺﾞｼ ｼｮｳｺ  963a5e03a33c7286d42d879c56ad9164
# 3         ｲｼｲ ｻｵﾘ  af62fd2487a09ddc1a01b70a1598b44c
# 4       ｵｻﾞﾜ ｼｮｳｺ  6b81b236e709df2b42986346a555c6e8
# 5        ﾀｼﾞﾏ ｶﾕｷ  e94c76750c29e8983d09c7381b7a44e6
# 6        ﾀｶﾊｼ ｱﾔﾐ  8629f71f39e65fe6ed093cd61747ca0f
# 7         ｵｲｶﾜ ﾏｷ  bd7fd2465a171f3034e1aa8d69629a9e
# 8       ｵｵﾇｷ ｺｽﾞｴ  abba94381f685fab04496f90c15c2988
# 9       ﾏｴﾔﾏ ﾐｽﾞｷ                                 a
# 10         ｼｷﾁ ﾘﾅ  846c6dc049c6ada89e1068e09f5df188
# 11       ｱﾍﾞ ﾏｻﾋﾛ  f02c6cfe69b743f11e5b6bfacd9ff6a6
# 12        ｻﾄｳ ﾘｮｳ                                 a
# 13  ｵｶﾞｻﾜﾗ ﾘｭｳﾉｽｹ  99fd2a28479326f36d9d71b0a5bf42c8
# 14     ﾆｲﾊﾗ ｼﾝﾍﾟｲ  2cfc90837c0cc72d821d6671e84d0d02
# 15        ｵｵｺ ｱﾘｻ  3e47d2b6a44c84ae9418a7f4c1a4e203
# 16     ﾅｶﾞｲ ｼｹﾞﾕｷ                                 a
# ...

# %%
#読み込むデータ設定
data_path = 'members2.csv'
#membersの読み込み
members = pd.read_csv(data_path, encoding = 'ANSI')
members_list_2 = members[['name', 'id']].fillna("a")
print(members_list_1)
print(members_list_2)
# Out:
#              name                                id
# 0      ﾌｸｼﾏ ｾｲﾀﾛｳ  25b8db9251d0c85065e7f4db9e493b72
# 1       ﾔﾅｷﾞｵｶ ｴﾐ  b127f88c4f12f2ebee7d50020cebc7dc
# 2      ﾂｶｺﾞｼ ｼｮｳｺ  963a5e03a33c7286d42d879c56ad9164
# 3         ｲｼｲ ｻｵﾘ  af62fd2487a09ddc1a01b70a1598b44c
# 4       ｵｻﾞﾜ ｼｮｳｺ  6b81b236e709df2b42986346a555c6e8
# 5        ﾀｼﾞﾏ ｶﾕｷ  e94c76750c29e8983d09c7381b7a44e6
# 6        ﾀｶﾊｼ ｱﾔﾐ  8629f71f39e65fe6ed093cd61747ca0f
# 7         ｵｲｶﾜ ﾏｷ  bd7fd2465a171f3034e1aa8d69629a9e
# 8       ｵｵﾇｷ ｺｽﾞｴ  abba94381f685fab04496f90c15c2988
# 9       ﾏｴﾔﾏ ﾐｽﾞｷ                                 a
# 10         ｼｷﾁ ﾘﾅ  846c6dc049c6ada89e1068e09f5df188
# 11       ｱﾍﾞ ﾏｻﾋﾛ  f02c6cfe69b743f11e5b6bfacd9ff6a6
# 12        ｻﾄｳ ﾘｮｳ                                 a
# 13  ｵｶﾞｻﾜﾗ ﾘｭｳﾉｽｹ  99fd2a28479326f36d9d71b0a5bf42c8
# 14     ﾆｲﾊﾗ ｼﾝﾍﾟｲ  2cfc90837c0cc72d821d6671e84d0d02
# 15        ｵｵｺ ｱﾘｻ  3e47d2b6a44c84ae9418a7f4c1a4e203
# 16     ﾅｶﾞｲ ｼｹﾞﾕｷ                                 a
# ...

# %%
#読み込むデータ設定
data_path = 'members3.csv'
#membersの読み込み
members = pd.read_csv(data_path, encoding = 'ANSI')
members_list_3 = members[['name', 'id']].fillna("a")
print(members_list_1)
print(members_list_2)
print(members_list_3)
# Out:
#              name                                id
# 0      ﾌｸｼﾏ ｾｲﾀﾛｳ  25b8db9251d0c85065e7f4db9e493b72
# 1       ﾔﾅｷﾞｵｶ ｴﾐ  b127f88c4f12f2ebee7d50020cebc7dc
# 2      ﾂｶｺﾞｼ ｼｮｳｺ  963a5e03a33c7286d42d879c56ad9164
# 3         ｲｼｲ ｻｵﾘ  af62fd2487a09ddc1a01b70a1598b44c
# 4       ｵｻﾞﾜ ｼｮｳｺ  6b81b236e709df2b42986346a555c6e8
# 5        ﾀｼﾞﾏ ｶﾕｷ  e94c76750c29e8983d09c7381b7a44e6
# 6        ﾀｶﾊｼ ｱﾔﾐ  8629f71f39e65fe6ed093cd61747ca0f
# 7         ｵｲｶﾜ ﾏｷ  bd7fd2465a171f3034e1aa8d69629a9e
# 8       ｵｵﾇｷ ｺｽﾞｴ  abba94381f685fab04496f90c15c2988
# 9       ﾏｴﾔﾏ ﾐｽﾞｷ                                 a
# 10         ｼｷﾁ ﾘﾅ  846c6dc049c6ada89e1068e09f5df188
# 11       ｱﾍﾞ ﾏｻﾋﾛ  f02c6cfe69b743f11e5b6bfacd9ff6a6
# 12        ｻﾄｳ ﾘｮｳ                                 a
# 13  ｵｶﾞｻﾜﾗ ﾘｭｳﾉｽｹ  99fd2a28479326f36d9d71b0a5bf42c8
# 14     ﾆｲﾊﾗ ｼﾝﾍﾟｲ  2cfc90837c0cc72d821d6671e84d0d02
# 15        ｵｵｺ ｱﾘｻ  3e47d2b6a44c84ae9418a7f4c1a4e203
# 16     ﾅｶﾞｲ ｼｹﾞﾕｷ                                 a
# ...

# %%
#読み込むデータ設定
data_path = 'members4.csv'
#membersの読み込み
members = pd.read_csv(data_path, encoding = 'ANSI')
members_list_4 = members[['name', 'id']].fillna("a")

# %%
#読み込むデータ設定
data_path = 'members5.csv'
#membersの読み込み
members = pd.read_csv(data_path, encoding = 'ANSI')
members_list_5 = members[['name', 'id']].fillna("a")

# %%
#読み込むデータ設定
data_path = 'members6.csv'
#membersの読み込み
members = pd.read_csv(data_path, encoding = 'ANSI')
members_list_6 = members[['name', 'id']].fillna("a")

# %%
members_list_1_fix = members_list_1
for index, Series in members_list_1.iterrows():
    id = Series['id']
    i = index
    if id == 'a':
        members_list_1_fix = members_list_1_fix.drop(i)
print(members_list_1_fix)
# Out:
#              name                                id
# 0      ﾌｸｼﾏ ｾｲﾀﾛｳ  25b8db9251d0c85065e7f4db9e493b72
# 1       ﾔﾅｷﾞｵｶ ｴﾐ  b127f88c4f12f2ebee7d50020cebc7dc
# 2      ﾂｶｺﾞｼ ｼｮｳｺ  963a5e03a33c7286d42d879c56ad9164
# 3         ｲｼｲ ｻｵﾘ  af62fd2487a09ddc1a01b70a1598b44c
# 4       ｵｻﾞﾜ ｼｮｳｺ  6b81b236e709df2b42986346a555c6e8
# 5        ﾀｼﾞﾏ ｶﾕｷ  e94c76750c29e8983d09c7381b7a44e6
# 6        ﾀｶﾊｼ ｱﾔﾐ  8629f71f39e65fe6ed093cd61747ca0f
# 7         ｵｲｶﾜ ﾏｷ  bd7fd2465a171f3034e1aa8d69629a9e
# 8       ｵｵﾇｷ ｺｽﾞｴ  abba94381f685fab04496f90c15c2988
# 10         ｼｷﾁ ﾘﾅ  846c6dc049c6ada89e1068e09f5df188
# 11       ｱﾍﾞ ﾏｻﾋﾛ  f02c6cfe69b743f11e5b6bfacd9ff6a6
# 13  ｵｶﾞｻﾜﾗ ﾘｭｳﾉｽｹ  99fd2a28479326f36d9d71b0a5bf42c8
# 14     ﾆｲﾊﾗ ｼﾝﾍﾟｲ  2cfc90837c0cc72d821d6671e84d0d02
# 15        ｵｵｺ ｱﾘｻ  3e47d2b6a44c84ae9418a7f4c1a4e203
# 17      ｴｸﾞﾁ ｼｮｳﾀ  312e805b3c3860b480de0e3bc6aa56ad
# 18     ｱﾘｶﾞ ｼｭﾝｽｹ  9a1b458ab0b1a9872e5109b368acb338
# 19    ﾀﾆｸﾞﾁ ｷｮｳﾍｲ  898612f07ccc985b92a24ac27f81346a
# ...

# %%
members_list_2_fix = members_list_2
for index, Series in members_list_2.iterrows():
    id = Series['id']
    i = index
    if id == 'a':
        members_list_2_fix = members_list_2_fix.drop(i)
print(members_list_2_fix)
# Out:
#              name                                id
# 0      ﾌｸｼﾏ ｾｲﾀﾛｳ  25b8db9251d0c85065e7f4db9e493b72
# 1       ﾔﾅｷﾞｵｶ ｴﾐ  b127f88c4f12f2ebee7d50020cebc7dc
# 2      ﾂｶｺﾞｼ ｼｮｳｺ  963a5e03a33c7286d42d879c56ad9164
# 3         ｲｼｲ ｻｵﾘ  af62fd2487a09ddc1a01b70a1598b44c
# 4       ｵｻﾞﾜ ｼｮｳｺ  6b81b236e709df2b42986346a555c6e8
# 5        ﾀｼﾞﾏ ｶﾕｷ  e94c76750c29e8983d09c7381b7a44e6
# 6        ﾀｶﾊｼ ｱﾔﾐ  8629f71f39e65fe6ed093cd61747ca0f
# 7         ｵｲｶﾜ ﾏｷ  bd7fd2465a171f3034e1aa8d69629a9e
# 8       ｵｵﾇｷ ｺｽﾞｴ  abba94381f685fab04496f90c15c2988
# 10         ｼｷﾁ ﾘﾅ  846c6dc049c6ada89e1068e09f5df188
# 11       ｱﾍﾞ ﾏｻﾋﾛ  f02c6cfe69b743f11e5b6bfacd9ff6a6
# 13  ｵｶﾞｻﾜﾗ ﾘｭｳﾉｽｹ  99fd2a28479326f36d9d71b0a5bf42c8
# 14     ﾆｲﾊﾗ ｼﾝﾍﾟｲ  2cfc90837c0cc72d821d6671e84d0d02
# 15        ｵｵｺ ｱﾘｻ  3e47d2b6a44c84ae9418a7f4c1a4e203
# 17      ｴｸﾞﾁ ｼｮｳﾀ  312e805b3c3860b480de0e3bc6aa56ad
# 18     ｱﾘｶﾞ ｼｭﾝｽｹ  9a1b458ab0b1a9872e5109b368acb338
# 19    ﾀﾆｸﾞﾁ ｷｮｳﾍｲ  898612f07ccc985b92a24ac27f81346a
# ...

# %%
members_list_3_fix = members_list_3
for index, Series in members_list_3.iterrows():
    id = Series['id']
    i = index
    if id == 'a':
        members_list_3_fix = members_list_3_fix.drop(i)
print(members_list_3_fix)
# Out:
#              name                                id
# 0      ﾌｸｼﾏ ｾｲﾀﾛｳ  25b8db9251d0c85065e7f4db9e493b72
# 1       ﾔﾅｷﾞｵｶ ｴﾐ  b127f88c4f12f2ebee7d50020cebc7dc
# 2      ﾂｶｺﾞｼ ｼｮｳｺ  963a5e03a33c7286d42d879c56ad9164
# 3         ｲｼｲ ｻｵﾘ  af62fd2487a09ddc1a01b70a1598b44c
# 4       ｵｻﾞﾜ ｼｮｳｺ  6b81b236e709df2b42986346a555c6e8
# 5        ﾀｼﾞﾏ ｶﾕｷ  e94c76750c29e8983d09c7381b7a44e6
# 6        ﾀｶﾊｼ ｱﾔﾐ  8629f71f39e65fe6ed093cd61747ca0f
# 7         ｵｲｶﾜ ﾏｷ  bd7fd2465a171f3034e1aa8d69629a9e
# 8       ｵｵﾇｷ ｺｽﾞｴ  abba94381f685fab04496f90c15c2988
# 10         ｼｷﾁ ﾘﾅ  846c6dc049c6ada89e1068e09f5df188
# 11       ｱﾍﾞ ﾏｻﾋﾛ  f02c6cfe69b743f11e5b6bfacd9ff6a6
# 13  ｵｶﾞｻﾜﾗ ﾘｭｳﾉｽｹ  99fd2a28479326f36d9d71b0a5bf42c8
# 14     ﾆｲﾊﾗ ｼﾝﾍﾟｲ  2cfc90837c0cc72d821d6671e84d0d02
# 15        ｵｵｺ ｱﾘｻ  3e47d2b6a44c84ae9418a7f4c1a4e203
# 17      ｴｸﾞﾁ ｼｮｳﾀ  312e805b3c3860b480de0e3bc6aa56ad
# 18     ｱﾘｶﾞ ｼｭﾝｽｹ  9a1b458ab0b1a9872e5109b368acb338
# 19    ﾀﾆｸﾞﾁ ｷｮｳﾍｲ  898612f07ccc985b92a24ac27f81346a
# ...

# %%
members_list_4_fix = members_list_4
for index, Series in members_list_4.iterrows():
    id = Series['id']
    i = index
    if id == 'a':
        members_list_4_fix = members_list_4_fix.drop(i)
#print(members_list_4_fix)

# %%
members_list_5_fix = members_list_5
for index, Series in members_list_5.iterrows():
    id = Series['id']
    i = index
    if id == 'a':
        members_list_5_fix = members_list_5_fix.drop(i)

# %%
members_list_6_fix = members_list_6
for index, Series in members_list_6.iterrows():
    id = Series['id']
    i = index
    if id == 'a':
        members_list_6_fix = members_list_6_fix.drop(i)

# %%
# 4.from_idとto_idのかぶりを取り除きnodeリストを完成させる
members_list= pd.concat([members_list_1_fix,members_list_2_fix])
members_list.reset_index(drop = True, inplace= True)
print(members_list)

members_list_pre =members_list.drop_duplicates(subset=['name','id'])

members_list_pre.reset_index(drop = True, inplace= True)
print(members_list_pre)
# Out:
#              name                                id
# 0      ﾌｸｼﾏ ｾｲﾀﾛｳ  25b8db9251d0c85065e7f4db9e493b72
# 1       ﾔﾅｷﾞｵｶ ｴﾐ  b127f88c4f12f2ebee7d50020cebc7dc
# 2      ﾂｶｺﾞｼ ｼｮｳｺ  963a5e03a33c7286d42d879c56ad9164
# 3         ｲｼｲ ｻｵﾘ  af62fd2487a09ddc1a01b70a1598b44c
# 4       ｵｻﾞﾜ ｼｮｳｺ  6b81b236e709df2b42986346a555c6e8
# 5        ﾀｼﾞﾏ ｶﾕｷ  e94c76750c29e8983d09c7381b7a44e6
# 6        ﾀｶﾊｼ ｱﾔﾐ  8629f71f39e65fe6ed093cd61747ca0f
# 7         ｵｲｶﾜ ﾏｷ  bd7fd2465a171f3034e1aa8d69629a9e
# 8       ｵｵﾇｷ ｺｽﾞｴ  abba94381f685fab04496f90c15c2988
# 9          ｼｷﾁ ﾘﾅ  846c6dc049c6ada89e1068e09f5df188
# 10       ｱﾍﾞ ﾏｻﾋﾛ  f02c6cfe69b743f11e5b6bfacd9ff6a6
# 11  ｵｶﾞｻﾜﾗ ﾘｭｳﾉｽｹ  99fd2a28479326f36d9d71b0a5bf42c8
# 12     ﾆｲﾊﾗ ｼﾝﾍﾟｲ  2cfc90837c0cc72d821d6671e84d0d02
# 13        ｵｵｺ ｱﾘｻ  3e47d2b6a44c84ae9418a7f4c1a4e203
# 14      ｴｸﾞﾁ ｼｮｳﾀ  312e805b3c3860b480de0e3bc6aa56ad
# 15     ｱﾘｶﾞ ｼｭﾝｽｹ  9a1b458ab0b1a9872e5109b368acb338
# 16    ﾀﾆｸﾞﾁ ｷｮｳﾍｲ  898612f07ccc985b92a24ac27f81346a
# ...

# %%
members_list= pd.concat([members_list_pre,members_list_3_fix])
members_list.reset_index(drop = True, inplace= True)
print(members_list)

members_list_pre =members_list.drop_duplicates(subset=['name','id'])

members_list_pre.reset_index(drop = True, inplace= True)
print(members_list_pre)
# Out:
#              name                                id
# 0      ﾌｸｼﾏ ｾｲﾀﾛｳ  25b8db9251d0c85065e7f4db9e493b72
# 1       ﾔﾅｷﾞｵｶ ｴﾐ  b127f88c4f12f2ebee7d50020cebc7dc
# 2      ﾂｶｺﾞｼ ｼｮｳｺ  963a5e03a33c7286d42d879c56ad9164
# 3         ｲｼｲ ｻｵﾘ  af62fd2487a09ddc1a01b70a1598b44c
# 4       ｵｻﾞﾜ ｼｮｳｺ  6b81b236e709df2b42986346a555c6e8
# 5        ﾀｼﾞﾏ ｶﾕｷ  e94c76750c29e8983d09c7381b7a44e6
# 6        ﾀｶﾊｼ ｱﾔﾐ  8629f71f39e65fe6ed093cd61747ca0f
# 7         ｵｲｶﾜ ﾏｷ  bd7fd2465a171f3034e1aa8d69629a9e
# 8       ｵｵﾇｷ ｺｽﾞｴ  abba94381f685fab04496f90c15c2988
# 9          ｼｷﾁ ﾘﾅ  846c6dc049c6ada89e1068e09f5df188
# 10       ｱﾍﾞ ﾏｻﾋﾛ  f02c6cfe69b743f11e5b6bfacd9ff6a6
# 11  ｵｶﾞｻﾜﾗ ﾘｭｳﾉｽｹ  99fd2a28479326f36d9d71b0a5bf42c8
# 12     ﾆｲﾊﾗ ｼﾝﾍﾟｲ  2cfc90837c0cc72d821d6671e84d0d02
# 13        ｵｵｺ ｱﾘｻ  3e47d2b6a44c84ae9418a7f4c1a4e203
# 14      ｴｸﾞﾁ ｼｮｳﾀ  312e805b3c3860b480de0e3bc6aa56ad
# 15     ｱﾘｶﾞ ｼｭﾝｽｹ  9a1b458ab0b1a9872e5109b368acb338
# 16    ﾀﾆｸﾞﾁ ｷｮｳﾍｲ  898612f07ccc985b92a24ac27f81346a
# ...

# %%
members_list= pd.concat([members_list_pre,members_list_4_fix])
members_list.reset_index(drop = True, inplace= True)
print(members_list)

members_list_pre =members_list.drop_duplicates(subset=['name','id'])

members_list_pre.reset_index(drop = True, inplace= True)
print(members_list_pre)
# Out:
#               name                                id
# 0       ﾌｸｼﾏ ｾｲﾀﾛｳ  25b8db9251d0c85065e7f4db9e493b72
# 1        ﾔﾅｷﾞｵｶ ｴﾐ  b127f88c4f12f2ebee7d50020cebc7dc
# 2       ﾂｶｺﾞｼ ｼｮｳｺ  963a5e03a33c7286d42d879c56ad9164
# 3          ｲｼｲ ｻｵﾘ  af62fd2487a09ddc1a01b70a1598b44c
# 4        ｵｻﾞﾜ ｼｮｳｺ  6b81b236e709df2b42986346a555c6e8
# 5         ﾀｼﾞﾏ ｶﾕｷ  e94c76750c29e8983d09c7381b7a44e6
# 6         ﾀｶﾊｼ ｱﾔﾐ  8629f71f39e65fe6ed093cd61747ca0f
# 7          ｵｲｶﾜ ﾏｷ  bd7fd2465a171f3034e1aa8d69629a9e
# 8        ｵｵﾇｷ ｺｽﾞｴ  abba94381f685fab04496f90c15c2988
# 9           ｼｷﾁ ﾘﾅ  846c6dc049c6ada89e1068e09f5df188
# 10        ｱﾍﾞ ﾏｻﾋﾛ  f02c6cfe69b743f11e5b6bfacd9ff6a6
# 11   ｵｶﾞｻﾜﾗ ﾘｭｳﾉｽｹ  99fd2a28479326f36d9d71b0a5bf42c8
# 12      ﾆｲﾊﾗ ｼﾝﾍﾟｲ  2cfc90837c0cc72d821d6671e84d0d02
# 13         ｵｵｺ ｱﾘｻ  3e47d2b6a44c84ae9418a7f4c1a4e203
# 14       ｴｸﾞﾁ ｼｮｳﾀ  312e805b3c3860b480de0e3bc6aa56ad
# 15      ｱﾘｶﾞ ｼｭﾝｽｹ  9a1b458ab0b1a9872e5109b368acb338
# 16     ﾀﾆｸﾞﾁ ｷｮｳﾍｲ  898612f07ccc985b92a24ac27f81346a
# ...

# %%
members_list= pd.concat([members_list_pre,members_list_5_fix])
members_list.reset_index(drop = True, inplace= True)
print(members_list)

members_list_pre =members_list.drop_duplicates(subset=['name','id'])

members_list_pre.reset_index(drop = True, inplace= True)
print(members_list_pre)
# Out:
#               name                                id
# 0       ﾌｸｼﾏ ｾｲﾀﾛｳ  25b8db9251d0c85065e7f4db9e493b72
# 1        ﾔﾅｷﾞｵｶ ｴﾐ  b127f88c4f12f2ebee7d50020cebc7dc
# 2       ﾂｶｺﾞｼ ｼｮｳｺ  963a5e03a33c7286d42d879c56ad9164
# 3          ｲｼｲ ｻｵﾘ  af62fd2487a09ddc1a01b70a1598b44c
# 4        ｵｻﾞﾜ ｼｮｳｺ  6b81b236e709df2b42986346a555c6e8
# 5         ﾀｼﾞﾏ ｶﾕｷ  e94c76750c29e8983d09c7381b7a44e6
# 6         ﾀｶﾊｼ ｱﾔﾐ  8629f71f39e65fe6ed093cd61747ca0f
# 7          ｵｲｶﾜ ﾏｷ  bd7fd2465a171f3034e1aa8d69629a9e
# 8        ｵｵﾇｷ ｺｽﾞｴ  abba94381f685fab04496f90c15c2988
# 9           ｼｷﾁ ﾘﾅ  846c6dc049c6ada89e1068e09f5df188
# 10        ｱﾍﾞ ﾏｻﾋﾛ  f02c6cfe69b743f11e5b6bfacd9ff6a6
# 11   ｵｶﾞｻﾜﾗ ﾘｭｳﾉｽｹ  99fd2a28479326f36d9d71b0a5bf42c8
# 12      ﾆｲﾊﾗ ｼﾝﾍﾟｲ  2cfc90837c0cc72d821d6671e84d0d02
# 13         ｵｵｺ ｱﾘｻ  3e47d2b6a44c84ae9418a7f4c1a4e203
# 14       ｴｸﾞﾁ ｼｮｳﾀ  312e805b3c3860b480de0e3bc6aa56ad
# 15      ｱﾘｶﾞ ｼｭﾝｽｹ  9a1b458ab0b1a9872e5109b368acb338
# 16     ﾀﾆｸﾞﾁ ｷｮｳﾍｲ  898612f07ccc985b92a24ac27f81346a
# ...

# %%
members_list= pd.concat([members_list_pre,members_list_6_fix])
members_list.reset_index(drop = True, inplace= True)
print(members_list)

members_list_pre =members_list.drop_duplicates(subset=['name','id'])

members_list_pre.reset_index(drop = True, inplace= True)
print(members_list_pre)
# Out:
#               name                                id
# 0       ﾌｸｼﾏ ｾｲﾀﾛｳ  25b8db9251d0c85065e7f4db9e493b72
# 1        ﾔﾅｷﾞｵｶ ｴﾐ  b127f88c4f12f2ebee7d50020cebc7dc
# 2       ﾂｶｺﾞｼ ｼｮｳｺ  963a5e03a33c7286d42d879c56ad9164
# 3          ｲｼｲ ｻｵﾘ  af62fd2487a09ddc1a01b70a1598b44c
# 4        ｵｻﾞﾜ ｼｮｳｺ  6b81b236e709df2b42986346a555c6e8
# 5         ﾀｼﾞﾏ ｶﾕｷ  e94c76750c29e8983d09c7381b7a44e6
# 6         ﾀｶﾊｼ ｱﾔﾐ  8629f71f39e65fe6ed093cd61747ca0f
# 7          ｵｲｶﾜ ﾏｷ  bd7fd2465a171f3034e1aa8d69629a9e
# 8        ｵｵﾇｷ ｺｽﾞｴ  abba94381f685fab04496f90c15c2988
# 9           ｼｷﾁ ﾘﾅ  846c6dc049c6ada89e1068e09f5df188
# 10        ｱﾍﾞ ﾏｻﾋﾛ  f02c6cfe69b743f11e5b6bfacd9ff6a6
# 11   ｵｶﾞｻﾜﾗ ﾘｭｳﾉｽｹ  99fd2a28479326f36d9d71b0a5bf42c8
# 12      ﾆｲﾊﾗ ｼﾝﾍﾟｲ  2cfc90837c0cc72d821d6671e84d0d02
# 13         ｵｵｺ ｱﾘｻ  3e47d2b6a44c84ae9418a7f4c1a4e203
# 14       ｴｸﾞﾁ ｼｮｳﾀ  312e805b3c3860b480de0e3bc6aa56ad
# 15      ｱﾘｶﾞ ｼｭﾝｽｹ  9a1b458ab0b1a9872e5109b368acb338
# 16     ﾀﾆｸﾞﾁ ｷｮｳﾍｲ  898612f07ccc985b92a24ac27f81346a
# ...

# %%
members_list_pre.to_csv("members_list_pre.csv", index = False)
